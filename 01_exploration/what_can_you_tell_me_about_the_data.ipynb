# %% [markdown]
# # What can you tell me about the data?
# ***
#
# ## Learning Objectives
# This section is all about the Discovery phase of Data Wrangling. After completing it you should be able to do:
# * **Data Exploration of CSV files** - *The student will be able to use pandas to read in a dataset and perform basic data exploration.*
# * **Data Analysis** - *The student will be able to use pandas to read in a dataset and perform basic data analysis.*
# * **Jupyter Notebooks** - *The student will be able to use Jupyter Notebooks to perform basic data exploration and analysis.*
# * **VSCode co-pilot** - *The student will be able to use VSCode co-pilot to perform basic data exploration and analysis.*
# ## Introduction
# Welcome to to your first lesson on Data Wrangling. In this lesson we will be covering the Discovery phase of Data Wrangling. This is the first phase of Data Wrangling and it is where we will be exploring our data and getting to know it. We will be using the pandas library to read in our data and perform basic data exploration and analysis. We will also be using Jupyter Notebooks and VSCode co-pilot to help us with our data exploration and analysis.
#
# Don't worry of all of this means nothing to you right now. We will be covering all of this in this lesson. By the end of this lesson you will be able to use pandas to read in a dataset and perform basic data exploration and analysis. You will also be able to use Jupyter Notebooks and VSCode co-pilot to help you with your data exploration and analysis.
#
# ## Data Frames
# Data Frames are one of the key building blocks that we'll be working with. What, might ask, is a Data Frame? Let's use the Q&A feature in VSCode to find out.
#
# q: What is a DataFrame?
# a: A DataFrame is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects. It is generally the most commonly used pandas object. Like Series, DataFrame accepts many different kinds of input: Dict of 1D ndarrays, lists, dicts, or Series 2-D numpy.ndarray Structured or record ndarray A Series Another DataFrame

# %% [markdown]
# Let's get started. We need to read the contents of the CSV file. How do we do that? Let's use the question mark to find out.

# %% [markdown]
# <!-- q: What is Pandas? -->
#
# <!-- q: How do I import a CSV file into a Pandas DataFrame? -->

# %%
import pandas as pd

df = pd.read_csv('sales_data_sample.csv', encoding='latin1')
# Get the first 5 rows
df.head()
# Out:
#    ORDERNUMBER   QUANTITYORDERED   PRICEEACH   ORDERLINENUMBER   SALES      \
# 0         10107                30       95.70                 2    2871.00
# 1         10121                34       81.35                 5    2765.90
# 2         10134                41       94.74                 2    3884.34
# 3         10145                45       83.26                 6    3746.70
# 4         10159                49      100.00                14    5205.27
#
#    ORDERDATE         STATUS       QTR_ID   MONTH_ID   YEAR_ID   ...  \
# 0  2/24/2003 0:00    Shipped            1          2      2003  ...
# 1  5/7/2003 0:00     Shipped            2          5      2003  ...
# 2  7/1/2003 0:00     Shipped            3          7      2003  ...
# 3  8/25/2003 0:00    Shipped            3          8      2003  ...
# 4  10/10/2003 0:00   Shipped            4         10      2003  ...
#
#    ADDRESSLINE1                                 ADDRESSLINE2   \
# 0  897 Long Airport Avenue
# 1  59 rue de l'Abbaye
# 2  27 rue du Colonel Pierre Avia
# 3  78934 Hillside Dr.
# 4  7734 Strong St.
#
#    CITY             STATE           POSTALCODE   COUNTRY       TERRITORY   \
# 0  NYC              NY              10022        USA           NA
# 1  Reims                            51100        France        EMEA
# 2  Paris                            75508        France        EMEA
# 3  Pasadena         CA              90003        USA           NA
# 4  San Francisco    CA                           USA           NA
#
#    CONTACTLASTNAME   CONTACTFIRSTNAME  DEALSIZE
# 0  Yu                Kwai                 Small
# 1  Henriot           Paul                 Small
# 2  Da Cunha          Daniel              Medium
# 3  Young             Julie               Medium
# 4  Brown             Julie               Medium
#
# [5 rows x 25 columns]

# %%
# Describe data 
df.describe()
# Out:
#        ORDERNUMBER   QUANTITYORDERED    PRICEEACH   ORDERLINENUMBER   \
# count   2823.000000       2823.000000  2823.000000       2823.000000
# mean   10258.725115         35.092809    83.658544          6.466171
# std       92.085478          9.741443    20.174277          4.225841
# min    10100.000000          6.000000    26.880000          1.000000
# 25%    10180.000000         27.000000    68.860000          3.000000
# 50%    10262.000000         35.000000    95.700000          6.000000
# 75%    10333.500000         43.000000   100.000000          9.000000
# max    10425.000000         97.000000   100.000000         18.000000
#
#           SALES          QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# 25%     2203.430000     2.000000     4.000000  2003.00000    68.000000
# 50%     3184.800000     3.000000     8.000000  2004.00000    99.000000
# 75%     4508.000000     4.000000    11.000000  2004.00000   124.000000
# max    14082.800000     4.000000    12.000000  2005.00000   214.000000

# %%
# Get the columns of the df
df.columns
# Out:
# Index(['ORDERNUMBER ', 'QUANTITYORDERED ', 'PRICEEACH ', 'ORDERLINENUMBER ',
#        'SALES    ', 'ORDERDATE       ', 'STATUS     ', 'QTR_ID ', 'MONTH_ID ',
#        'YEAR_ID ', 'PRODUCTLINE      ', 'MSRP ', 'PRODUCTCODE ',
#        'CUSTOMERNAME                         ', 'PHONE             ',
#        'ADDRESSLINE1                               ', 'ADDRESSLINE2 ',
#        'CITY           ', 'STATE         ', 'POSTALCODE ', 'COUNTRY     ',
#        'TERRITORY ', 'CONTACTLASTNAME ', 'CONTACTFIRSTNAME ', 'DEALSIZE'],
#       dtype='object')

# %%
# Remove the White Space in the column names
df.columns = df.columns.str.replace(' ', '')

# Get the order that are higher than 10000
df[df['SALES'] > 10000]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 30          10150               45      100.0                8  10993.5
# 43          10304               47      100.0                6  10172.7
# 44          10312               48      100.0                3  11623.7
# 53          10424               50      100.0                6  12001.0
# 104         10403               66      100.0                9  11886.6
# 188         10127               46      100.0                2  11279.2
# 198         10247               44      100.0                2  10606.2
# 598         10407               76      100.0                2  14082.8
# 744         10322               50      100.0                6  12536.5
# 1062        10412               60      100.0                9  11887.8
# 1133        10333               46      100.0                2  11336.7
# 1188        10406               65      100.0                1  10468.9
# 1839        10339               55      100.0               13  10758.0
# 1995        10405               76      100.0                3  11739.7
# 2117        10375               43      100.0                2  10039.6
# 2505        10388               46      100.0                2  10066.6
#
#              ORDERDATE       STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 30    9/19/2003 0:00    Shipped           3         9     2003  ...
# 43    10/11/2004 0:00   Shipped           4        10     2004  ...
# 44    10/21/2004 0:00   Shipped           4        10     2004  ...
# 53    5/31/2005 0:00    In Process        2         5     2005  ...
# 104   4/8/2005 0:00     Shipped           2         4     2005  ...
# 188   6/3/2003 0:00     Shipped           2         6     2003  ...
# 198   5/5/2004 0:00     Shipped           2         5     2004  ...
# 598   4/22/2005 0:00    On Hold           2         4     2005  ...
# 744   11/4/2004 0:00    Shipped           4        11     2004  ...
# 1062  5/3/2005 0:00     Shipped           2         5     2005  ...
# 1133  11/18/2004 0:00   Shipped           4        11     2004  ...
# 1188  4/15/2005 0:00    Disputed          2         4     2005  ...
# 1839  11/23/2004 0:00   Shipped           4        11     2004  ...
# 1995  4/14/2005 0:00    Shipped           2         4     2005  ...
# 2117  2/3/2005 0:00     Shipped           1         2     2005  ...
# 2505  3/3/2005 0:00     Shipped           1         3     2005  ...
#
#                                      ADDRESSLINE1   ADDRESSLINE2  \
# 30      Bronz Sok., Bronz Apt. 3/6 Tesvikiye
# 43      67, avenue de l'Europe
# 44    5677 Strong St.
# 53      C/ Moralzarzal, 86
# 104   Berkeley Gardens 12  Brewery
# 188   4092 Furth Circle                            Suite 400
# 198     Software Engineering Center, SEC Oy
# 598   3086 Ingle Ln.
# 744   2304 Long Airport Avenue
# 1062    C/ Moralzarzal, 86
# 1133  5557 North Pendale Street
# 1188  Vinb'ltet 34
# 1839  2-2-8 Roppongi
# 1995    24, place Kluber
# 2117    67, rue des Cinquante Otages
# 2505  1785 First Street
#
#                  CITY           STATE   POSTALCODE       COUNTRY   TERRITORY  \
# 30    Singapore                        79903        Singapore     Japan
# 43    Versailles                       78000        France        EMEA
# 44    San Rafael       CA              97562        USA           NA
# 53    Madrid                           28034        Spain         EMEA
# 104   Liverpool                        WX1 6LT      UK            EMEA
# 188   NYC              NY              10022        USA           NA
# 198   Espoo                            FIN-02271    Finland       EMEA
# 598   San Jose         CA              94217        USA           NA
# 744   Nashua           NH              62005        USA           NA
# 1062  Madrid                           28034        Spain         EMEA
# 1133  San Francisco    CA                           USA           NA
# 1188  Kobenhavn                        1734         Denmark       EMEA
# 1839  Minato-ku        Tokyo           106-0032     Japan         Japan
# 1995  Strasbourg                       67000        France        EMEA
# 2117  Nantes                           44000        France        EMEA
# 2505  New Bedford      MA              50553        USA           NA
#
#        CONTACTLASTNAME   CONTACTFIRSTNAME DEALSIZE
# 30    Natividad         Eric                 Large
# 43    Tonini            Daniel               Large
# 44    Nelson            Valarie              Large
# 53    Freyre            Diego                Large
# 104   Devon             Elizabeth            Large
# 188   Young             Jeff                 Large
# 198   Suominen          Kalle                Large
# 598   Frick             Sue                  Large
# 744   Young             Valarie              Large
# 1062  Freyre            Diego                Large
# 1133  Murphy            Julie                Large
# 1188  Petersen          Jytte                Large
# 1839  Shimamura         Akiko                Large
# 1995  Citeaux           Frederique           Large
# 2117  Labrune           Janine               Large
# 2505  Benitez           Violeta              Large
#
# [16 rows x 25 columns]

# %%
import openpyxl

workbook = openpyxl.load_workbook("my_workbook.xlsx")

sheet_names = workbook.sheetnames

for sheet_name in sheet_names:
    print(sheet_name)


numbers = [1, 2, 3]

for number in numbers:
    print(number)
